# %% [markdown]
# # Handing missing values:
#
#
# I am going to follow the steps mentioned below in this notebook:
#
# * [Take a first look at the data](#Take-a-first-look-at-the-data)
# * [See how many missing data points we have](#See-how-many-missing-data-points-we-have)
# * [Figure out why the data is missing](#Figure-out-why-the-data-is-missing)
# * [Drop missing values](#Drop-missing-values)
# * [Filling in missing values](#Filling-in-missing-values)
#
# Let's get started!

# %% [markdown]
# ## Take a first look at the data
# ________
#
# The first thing we'll need to do is load in the libraries and datasets we'll be using. For today, I'll be using a dataset of books with different specifications.

# %%
# modules we'll use
import pandas as pd
import numpy as np

# read in all our data
books_data = pd.read_csv("BL-Flickr-Images-Book.csv")

# %% [markdown]
# The first thing I do when I get a new dataset is take a look at some of it. This lets me see that it all read in correctly and get an idea of what's going on with the data. In this case, I'm looking to see if I see any missing values, which will be reprsented with `NaN` or `None`.

# %%
# look at a few rows of the books_data file. I can see a handful of missing data already!
books_data.sample(5)
# Out:
#       Identifier Edition Statement Place of Publication Date of Publication  \
# 2942     1445091               NaN            Cape Town                1855
# 365       151917               NaN                Paris                1858
# 6590     3230083               NaN     Château-Thierry                1894
# 8190     3993027               NaN    Frankfurt am Main                1838
# 880       434723               NaN               London                1787
#
#                    Publisher  \
# 2942        S. Solomon & Co.
# 365                      NaN
# 6590                     NaN
# 8190                     NaN
# 880   G. G. J. & J. Robinson
#
#                                                   Title  \
# 2942  Sunshine and Cloud; or, light thrown on a dark...
# 365   Les Voyages de Améric Vespuce au compte de l'...
# 6590  Un Coin de la Champagne et du Valois au XVIIe ...
# 8190  Zur Sprach- und Geschichtsforschung der neuest...
# 880   The Midnight Hour. A comedy, in three acts. Fr...
#
#                                                  Author  \
# 2942                                 GODLONTON, Robert.
# 365              AVEZAC-MACAYA, Marie Armand Pascal d'.
# 6590                                        SALESSE, I.
# 8190       XYLANDER, Karl August Anton Aloys Josef von.
# 880   BOURLIN, Antoine Jean - calling himself Dumaniant
#
#                                            Contributors  Corporate Author  \
# 2942                  STOCKENSTROM, Andries - Sir, Bart               NaN
# 365   VARNHAGEN, Francisco Adolfo de - Viscount de P...               NaN
# 6590                                  HÉRICART, Marie.               NaN
# 8190                      SCHOTT, Wilhelm - Orientalist               NaN
# 880                                      Inchbald - Mrs               NaN
#
#       Corporate Contributors Former owner  Engraver Issuance type  \
# 2942                     NaN          NaN       NaN   monographic
# 365                      NaN          NaN       NaN   monographic
# 6590                     NaN          NaN       NaN   monographic
# 8190                     NaN          NaN       NaN   monographic
# 880                      NaN          NaN       NaN   monographic
#
#                                              Flickr URL  \
# 2942  http://www.flickr.com/photos/britishlibrary/ta...
# 365   http://www.flickr.com/photos/britishlibrary/ta...
# 6590  http://www.flickr.com/photos/britishlibrary/ta...
# 8190  http://www.flickr.com/photos/britishlibrary/ta...
# 880   http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 2942               British Library HMNTS 9004.h.30.(3.)
# 365                    British Library HMNTS 10480.e.9.
# 6590                  British Library HMNTS 010171.i.2.
# 8190  British Library HMNTS 9007.dd.3.|British Libra...
# 880   British Library HMNTS 643.i.11.(2.)|British Li...

# %% [markdown]
# ## See how many missing data points we have
# ___
#
# Ok, now we know that we do have some missing values. Let's see how many we have in each column.

# %%
# get the number of missing data points per column
missing_values_count = books_data.isnull().sum()
missing_values_count
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %% [markdown]
# That seems like a lot! It might be helpful to see what percentage of the values in our dataset were missing to give us a better sense of the scale of this problem:

# %%
# how many total missing values do we have?
total_cells = np.product(books_data.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
(total_missing/total_cells) * 100
# Out:
# 37.66139736937372

# %% [markdown]
# Wow, more than a quarter of the cells in this dataset are empty! In the next step, we're going to take a closer look at some of the columns with missing values and try to figure out what might be going on with them.

# %% [markdown]
# ## Figure out why the data is missing
# ____
#
#
# Before dealing with missing values, we'll need to use our intution to figure out why the value is missing. One important question that we can ask ourselves is **if the values of a column are missing becuase they weren't recorded or because they don't exist**?
#
# If a value is missing because it doens't exist (like the height of the oldest child of someone who doesn't have any children) then it doesn't make sense to try and guess what it might be. These values we probalby do want to keep as NaN. On the other hand, if a value is missing becuase it wasn't recorded, then we can try to guess what it might have been based on the other values in that column and row which we call as `imputation`.

# %%
# look at the # of missing points in all columns
missing_values_count
# Out:
# Identifier                   0
# Edition Statement         7514
# Place of Publication         0
# Date of Publication        181
# Publisher                 4195
# Title                        0
# Author                    1778
# Contributors                 0
# Corporate Author          8287
# Corporate Contributors    8287
# Former owner              8286
# Engraver                  8287
# Issuance type                0
# Flickr URL                   0
# Shelfmarks                   0
# dtype: int64

# %%
books_data.shape
# Out:
# (8287, 15)

# %% [markdown]
# ## Drop missing values
# ____
#
# **Let us handle missing values for different columns one by one.**
# >We can see that for `Edition Statement` approx. 90% of the data is missing since not every book has a new edition so it is fair to remove this column.
# Similarly for columns like `Corporate Author`,`Corporate Contributors`,`Former owner`and `Engraver`, 100% of the data is missing so we will remove these columns as well.

# %%
books_data.drop(['Edition Statement','Corporate Author','Corporate Contributors','Former owner','Engraver'], axis = 1, inplace = True)

# %% [markdown]
# ## Filling in missing values
# _______
#  Filling in the missing values is called **Imputation.**
#
# >`Author` column has 1778 missing values. Since Authors column would have a different specific value each time, we will treat these missing values as a specific categorty. Hence we will replace the NaN values with a Na value.
# Similarly, the same relacement could be done for the Publisher column as well.

# %%
# Replacing NaN values with Na for Author 
books_data['Author'].replace(to_replace= np.nan, value="Na", inplace=True)

# %%
books_data.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London         1879 [1878]
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors Issuance type  \
# 0      A. A.                               FORBES, Walter.   monographic
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 3  A., E. S.                   Appleyard, Ernest Silvanus.   monographic
# 4  A., E. S.                           BROOME, John Henry.   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.

# %%
# Replacing NaN values with Na for Publisher
books_data['Publisher'].fillna("Na", inplace = True)

# %% [markdown]
# >For `Date of Publication` column we can impute some values for NaN values. But before doing that, we need to clean the column as it contains certain unwanted characters. Hence we will first remove these unwanted characters and then do the `imputation`.

# %%
#Cleaning Date of Publication
unwanted_characters = ['[', ',', '-','.',']','?','/']

def clean_dates(dop):
    dop = str(dop)
    if dop.startswith('[') or dop == 'nan':
        return 'NaN'
    for character in unwanted_characters:
        if character in dop:
            character_index = dop.find(character)
            dop = dop[:character_index]
    return dop

books_data['Date of Publication'] = books_data['Date of Publication'].apply(clean_dates)
books_data.head()
# Out:
#    Identifier      Place of Publication Date of Publication  \
# 0         206                    London               1879
# 1         216  London; Virtue & Yorston                1868
# 2         218                    London                1869
# 3         472                    London                1851
# 4         480                    London                1857
#
#                Publisher                                              Title  \
# 0       S. Tinsley & Co.                  Walter Forbes. [A novel.] By A. A
# 1           Virtue & Co.  All for Greed. [A novel. The dedication signed...
# 2  Bradbury, Evans & Co.  Love the Avenger. By the author of “All for Gr...
# 3          James Darling  Welsh Sketches, chiefly ecclesiastical, to the...
# 4   Wertheim & Macintosh  [The World in which I live, and my place in it...
#
#       Author                                  Contributors Issuance type  \
# 0      A. A.                               FORBES, Walter.   monographic
# 1  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 2  A., A. A.  BLAZE DE BURY, Marie Pauline Rose - Baroness   monographic
# 3  A., E. S.                   Appleyard, Ernest Silvanus.   monographic
# 4  A., E. S.                           BROOME, John Henry.   monographic
#
#                                           Flickr URL  \
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...
#
#                             Shelfmarks
# 0    British Library HMNTS 12641.b.30.
# 1    British Library HMNTS 12626.cc.2.
# 2    British Library HMNTS 12625.dd.1.
# 3  British Library HMNTS 10369.bbb.15.
# 4     British Library HMNTS 9007.d.28.

# %% [markdown]
# >Now that we have removed the unwanted characters from the `Date of Publication` column, we can impute the NaN values. One way to do that is to sort the values in ascending order and then fill the NaN values with the values occuring just after them.(This makes a lot of sense for datasets where the observations have some sort of logical order to them.)

# %%
# Arranging the values in ascending order
sorted_df = books_data.sort_values(by = 'Date of Publication', ascending = True)
# replace all NaN's with the values that comes directly after it in the same column, 
sorted_df.fillna(method = 'bfill', axis=0)
# Out:
#       Identifier                               Place of Publication  \
# 1081      516336                                             London
# 5944     2938347                                              Paris
# 2934     1442148                                           Lond[on]
# 2817     1376528                                             London
# 7778     3823617                                             London
# 4852     2396288                                             London
# 895       439737                                             London
# 6528     3212310                                             London
# 2035      896061                                             London
# 1453      660893                                             London
# 7326     3582834                                             London
# 3515     1704542                                             London
# 4613     2299790                                             London
# 6160     3022543                                             London
# 3094     1509795                                             London
# 3757     1823663                                             London
# 1080      515955                                             London
# 7776     3823253                                             London
# 6161     3022545                                             London
# 6898     3370994                                             London
# 2604     1253024                                             London
# 1454      660943                                             London
# 2479     1186704                                             London
# 7053     3442119                                             London
# 2603     1253003                                             London
# 564       241254                                             London
# 5037     2486393                                             London
# 3187     1553618                                             Oxford
# 4984     2462653                                             London
# 4985     2462657                                           London,]
# ...          ...                                                ...
# 6489     3191783                                           New York
# 6487     3191349                                           New York
# 501       207672                                             London
# 3673     1769127                                             Zurich
# 3607     1751091                                             London
# 6548     3214222                                    London, [1874.]
# 6550     3214363              pp. 23. T. Fisher Unwin: London, 1883
# 6637     3263773        pp. 80. Andrew Churchman: Hammersmith, 1890
# 3621     1759168                                            Wrexham
# 3625     1760060                                            Chester
# 6623     3257016                                       London, 1838
# 6622     3256861                                     New York, 1866
# 459       179539                                             London
# 6617     3254078                                             London
# 6615     3252024                   pp. 46. E. Mathews: London, 1898
# 464       182354                                             London
# 6608     3245710                       pp. 16. C. Fox: London, 1835
# 6603     3242628                                         Birmingham
# 467       183576                                             London
# 6583     3226247                                             London
# 6581     3226025                                             London
# 3644     1761576  A[ppledore]. P[rivate]. P[ress: New-Haven, Con...
# 3650     1762496                                     Great Yarmouth
# 1247      559884                                             London
# 2374     1045858                                             London
# 1240      558969                                             London
# 6558     3220051                                          Barcelona
# 5944                                                 Na
# 2934                               GNAPHEUS, Gulielmus.
# 2817                                                 Na
# 7778                                             W., R.
# 4852                          MARSTON, John - Dramatist
# 895                                 BOWES, Jerome - Sir
# 6528                                             S., E.
# 2035                                     Dekker, Thomas
# 1453                                    Chapman, George
# 7326                                    Tasso, Torquato
# 3515                                     Chettle, Henry
# 4613                               M., P. - and F. (N.)
# 6160                                             R., W.
# 3094  GREVILLE, Fulke - Baron Brooke|Greville, Fulke...
# 3757                                                 Na
# 1080                                      BUCK, George.
# 7776                                      W., J. - Gent
# 6161                                             R., W.
# 6898                         SHIRLEY, Henry - Dramatist
# 2604                         FLETCHER, John - Dramatist
# 1454                                    Chapman, George
# 2479                                          F., B. J.
# 7053                                                 Na
# 2603                         FLETCHER, John - Dramatist
# 564                                  BEAUMONT, Francis.
# 5037                      MIDDLETON, Thomas - Dramatist
# 3187                             H., S. - A.B., e C. Ex
# 4984                                                 Na
# 4985                                                 Na
# ...                                                 ...
# 6489                                       Ruskin, John
# 6487                                       Ruskin, John
# 501                                     BARR, Matthias.
# 3673                                                 Na
# 3607                            HOZIER, Henry Montague.
# 6548                                          S., T. B.
# 6550                                             S., W.
# 6637                                     SAYERS, Harry.
# 3621                              HUGHES, John Ceiriog.
# 3625                                     Hughes, Thomas
# 6623                          SAUNDERS, John - Novelist
# 6622                               SAUNDERS, Frederick.
# 459   BALDERSTON, Robert R. - and BALDERSTON (Margaret)
# 6617                       SARTORIUS, C. - of Darmstadt
# 6615                                    SARGANT, Alice.
# 464                  BALL, afterwards FITZBALL, Edward.
# 6608                                                 Na
# 6603                      SANDERS, Charles - Malefactor
# 467                                                  Na
# 6583                  SAINT-LAMBERT, Jean François de.
# 6581                     SAINT JOHN, Percy Bolingbroke.
# 3644                                       Hugo, Victor
# 3650           HUKE, Alfred Norton - and HUKE (William)
# 1247                                             C., E.
# 2374                                                 Na
# 1240                                       BYSTRÖM, H.
# 6558         SAEZ, afterwards SAEZ DE MELGAR, Faustina.
# 6549                                              W. S.
# 5400             NOEL, Roden Berkeley Wriothesley - Hon
# 6911                                                 Na
#
#                                            Contributors Issuance type  \
# 1081                                B., C.|Kean, Edmund   monographic
# 5944                                   REGIUS, Raphael.   monographic
# 2934                                   PALSGRAVE, John.   monographic
# 2817                                       DROUT, John.   monographic
# 7778                         WILSON, Robert - Dramatist   monographic
# 4852                                             M., I.   monographic
# 895   TETHERTON, Robert.|WILSON, Edward - Murderer|W...   monographic
# 6528                                  SHARPHAM, Edward.   monographic
# 2035                          WEBSTER, John - Dramatist   monographic
# 1453             HERBERT, Philip - 4th Earl of Pembroke   monographic
# 7326                             REYNOLDS, Henry - Poet   monographic
# 3515                            LENNARD, Henry Barrett.   monographic
# 4613                F., N.|FIELD, Nathaniel - Dramatist   monographic
# 6160                        ROWLEY, William - Dramatist   monographic
# 3094                        GROSART, Alexander Balloch.   monographic
# 3757                              DAY, John - Dramatist   monographic
# 1080                                 BUCK, George - Sir   monographic
# 7776                          BOWYER, William - Soldier   monographic
# 6161                        ROWLEY, William - Dramatist   monographic
# 6898                                             K., I.   monographic
# 2604                                    BROME, Richard.   monographic
# 1454                                     Shirley, James   monographic
# 2479                         FLETCHER, John - Dramatist   monographic
# 7053                                    ZOUCH, Richard.   monographic
# 2603                                     Shirley, James   monographic
# 564                              BLAIKELOCKE, Laurence.   monographic
# 5037                                      M., T. - Gent   monographic
# 3187  HARDING, Samuel - of Exeter College, Oxford|P....   monographic
# 4984                                BRATHWAIT, Richard.   monographic
# 4985                                BRATHWAIT, Richard.   monographic
# ...                                                 ...           ...
# 6489                     TUTHILL, Louisa Caroline - Mrs   monographic
# 6487                             WRIGHT, James Osborne.   monographic
# 501                                 GIACOMELLI, Hector.   monographic
# 3673                                        BELL, F. A.   monographic
# 3607   Adams, W. H. Davenport (William Henry Davenport)   monographic
# 6548                          SMITHIES, Thomas Bywater.   monographic
# 6550                           FURNISS, Harry.|SIMS, W.   monographic
# 6637                                     TWELLS, Henry.   monographic
# 3621                                  ROBERTS, Eleazar.   monographic
# 3625                             MEASOM, George Samuel.   monographic
# 6623                   SAUNDERS, Mary - Poetical Writer   monographic
# 6622                          HOOPER, Edward - Engraver   monographic
# 459                               BALDERSTON, Margaret.   monographic
# 6617   GASPEY, Thomas William.|RUGENDAS, Johann Moritz.   monographic
# 6615                           STRANG, William - Artist   monographic
# 464         WALLACE, William Vincent - Musical Composer   monographic
# 6608                           SEYMOUR, Robert - Artist   monographic
# 6603            ROGERS, George - Shoemaker at Allersley   monographic
# 467                                 Gilbert, John - Sir   monographic
# 6583                            STEELE, Elizabeth - Mrs   monographic
# 6581                            DICKS, John - Publisher   monographic
# 3644                             LINTON, William James.   monographic
# 3650                                     HUKE, William.   monographic
# 1247                                    CAPELL, Edward.   monographic
# 2374                                  PLIMSOLL, Samuel.   monographic
# 1240                                       ASKER, Kurt.   monographic
# 6558                                   PLANAS, Eusebio.   monographic
# 6549              SALISBURY, William - Rector of Morton   monographic
# 5400             HICKEY, Emily Henrietta.|NISBET, Hume.   monographic
# 6911                      DeWint, Peter|LIGHT, William.   monographic
#
#                                              Flickr URL  \
# 1081  http://www.flickr.com/photos/britishlibrary/ta...
# 5944  http://www.flickr.com/photos/britishlibrary/ta...
# 2934  http://www.flickr.com/photos/britishlibrary/ta...
# 2817  http://www.flickr.com/photos/britishlibrary/ta...
# 7778  http://www.flickr.com/photos/britishlibrary/ta...
# 4852  http://www.flickr.com/photos/britishlibrary/ta...
# 895   http://www.flickr.com/photos/britishlibrary/ta...
# 6528  http://www.flickr.com/photos/britishlibrary/ta...
# 2035  http://www.flickr.com/photos/britishlibrary/ta...
# 1453  http://www.flickr.com/photos/britishlibrary/ta...
# 7326  http://www.flickr.com/photos/britishlibrary/ta...
# 3515  http://www.flickr.com/photos/britishlibrary/ta...
# 4613  http://www.flickr.com/photos/britishlibrary/ta...
http://www.flickr.com/photos/britishlibrary/ta...
#
#                                              Shelfmarks
# 1081                   British Library HMNTS 11779.f.9.
# 5944                   British Library HMNTS 1077.f.39.
# 2934  British Library HMNTS C.34.f.2.|British Librar...
# 2817                   British Library HMNTS 11621.f.9.
# 7778                    British Library HMNTS 643.c.28.
# 4852  British Library HMNTS Ashley 1099.|British Lib...
# 895                    British Library HMNTS 1077.i.17.
# 6528                     British Library HMNTS 643.c.9.
# 2035  British Library HMNTS 644.b.25.|British Librar...
# 1453  British Library HMNTS C.45.b.9.|British Librar...
# 7326  British Library HMNTS 643.d.82.|British Librar...
# 3515  British Library HMNTS 644.b.11.|British Librar...
# 4613  British Library HMNTS 644.e.85.|British Librar...
# 6160  British Library HMNTS C.12.f.1.(2.)|British Li...
# 3094  British Library HMNTS 644.i.88.|British Librar...
# 3757  British Library HMNTS 644.d.76.|British Librar...
# 1080  British Library HMNTS 1077.i.12.|British Libra...
# 7776  British Library HMNTS 643.c.44.|British Librar...
# 6161  British Library HMNTS 644.c.16.|British Librar...
# 6898  British Library HMNTS 644.c.55.|British Librar...
# 2604                    British Library HMNTS 644.b.28.
# 1454  British Library HMNTS 643.d.2.|British Library...
# 2479  British Library HMNTS 161.i.47.|British Librar...
# 7053  British Library HMNTS 643.c.50.|British Librar...
# 2603  British Library HMNTS 644.b.29.|British Librar...
# 564   British Library HMNTS 1077.i.18.|British Libra...
# 5037  British Library HMNTS 644.f.8.|British Library...
# 3187  British Library HMNTS 644.e.26.|British Librar...
# 4984  British Library HMNTS 644.d.30.|British Librar...
# 4985                    British Library HMNTS 644.d.28.
# ...                                                 ...
# 6489                 British Library HMNTS 12272.bbb.1.
# 6487                 British Library HMNTS 11612.df.23.
# 501                   British Library HMNTS 11651.h.15.
# 3673                   British Library HMNTS 10215.b.5.
# 3607  British Library HMNTS 9078.h.14.|British Libra...
# 6548                  British Library HMNTS 11652.g.32.
# 6550                  British Library HMNTS 11651.m.10.
# 6637                  British Library HMNTS 011650.g.7.
# 3621              British Library HMNTS 11781.f.47.(6.)
# 3625                   British Library HMNTS 10358.f.8.
# 6623                  British Library HMNTS 11647.ee.8.
# 6622                  British Library HMNTS 11651.g.16.
# 459                  British Library HMNTS 10358.ccc.33
# 6617  British Library HMNTS 10480.f.9.|British Libra...
# 6615                  British Library HMNTS 11651.m.36.
# 464               British Library HMNTS 11781.d.23.(3.)
# 6608                 British Library HMNTS 11645.ff.22.
# 6603               British Library HMNTS 1077.g.37.(7.)
# 467                   British Library HMNTS 11601.ee.8.
# 6583                British Library HMNTS 643.k.17.(8.)
# 6581                   British Library HMNTS 12620.i.3.
# 3644             British Library HMNTS 011652.m.13.(3.)
# 3650              British Library HMNTS 10347.c.15.(3.)
# 1247                    British Library HMNTS 644.k.10.
# 2374                British Library HMNTS 12638.bbb.19.
# 1240                  British Library HMNTS 10496.cc.7.
# 6558                   British Library HMNTS 10007.m.1.
# 6549            British Library HMNTS 11643.bbb.20.(4.)
# 5400                  British Library HMNTS 11652.i.50.
# 6911                  British Library HMNTS 10129.e.22.
#
# [8287 rows x 10 columns]

# %% [markdown]
# >Now that we have dealt with all the missing values of different columns, let us check it once.

# %%
sorted_df.isnull().sum()
# Out:
# Identifier              0
# Place of Publication    0
# Date of Publication     0
# Publisher               0
# Title                   0
# Author                  0
# Contributors            0
# Issuance type           0
# Flickr URL              0
# Shelfmarks              0
# dtype: int64
